# %%
import cv2 as cv
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cap = cv.VideoCapture(0)
ret, frame = cap.read()
plt.imshow(frame)
plt.show()

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook

face_cascade = cv.CascadeClassifier('haarcascade_frontalface_default.xml')
smile_cascade = cv.CascadeClassifier('haarcascade_smile.xml')
eye_cascade = cv.CascadeClassifier('haarcascade_eye.xml')

for i in range(10):
    plt.close()
    cap = cv.VideoCapture(0)
    ret, img = cap.read()

    # img = cv.resize(img, (400, 400))
    gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#     print('FACES', faces)

    for (x, y, w, h) in faces:
        cv.rectangle(gray, (x, y), (x+w, y+h), (255, 0, 0), 2)
        roi_gray = gray[y:y+h, x:x+w]

        eyes = eye_cascade.detectMultiScale(roi_gray)
#         print('EYES', eyes)
        for (ex, ey, ew, eh) in eyes:
            cv.rectangle(roi_gray, (ex, ey), (ex+ew, ey+eh), (0, 255, 0), 2)

    #     smiles = smile_cascade.detectMultiScale(roi_gray)
    #     print('SMILES', smiles)
    #     for (ex, ey, ew, eh) in smiles:
    #         cv.rectangle(roi_gray, (ex, ey), (ex+ew, ey+eh), (0, 255, 0), 2)

    plt.imshow(gray)
    plt.savefig('photos/{}.png'.format(i), )
#     plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
cap.release()

# %%
import ipywidgets as widgets

# %%
widgets.FloatSlider(
    value=7.5,
    min=0,
    max=10.0,
    step=0.1,
    description='Test:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='.1f',
)
# Out:
# FloatSlider(value=7.5, continuous_update=False, description='Test:', max=10.0, readout_format='.1f')

# %%
plt.savefig

# %%
import os

for i in os.listdir('photos'):
    IPython.display.display(IPython.display.Image('photos/{}'.format(i)))

# %%
gray

# %%
import IPython
from io import StringIO
import PIL
from PIL import Image

def showarray(a, fmt='jpeg'):
    IPython.display.display(IPython.display.Image(data=f.getvalue()))

# %%
IPython.display.display(IPython.display.Image('test.jpg'))

# %%
import autopy

# %%
p = autopy.mouse.location()
p
# Out:
# (1279.99609375, 799.99609375)

# %%
xmax = 1280
ymax = 800

# %%
autopy.mouse.move(100, 100)

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
# %matplotlib inline

face_cascade = cv.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade = cv.CascadeClassifier('haarcascade_eye.xml')

while True:
# for i in range(1):
    cap = cv.VideoCapture(0)
    ret, img = cap.read()

#     img = cv.resize(img, (400, 400))
    gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#     print('FACES', faces)

    for (x, y, w, h) in faces:
#         cv.rectangle(gray, (x, y), (x+w, y+h), (255, 0, 0), 2)
        cv.rectangle(gray, (x, y), (x+ (w//2), y+(h//2)), (255, 0, 0), 2)
        
        cursor_x = abs(xmax - (x + (w//2)))
        cursor_y = y + (h//2)
        
        autopy.mouse.move(cursor_x, cursor_y)
        
#     plt.imshow(gray)
#     plt.show()
# Out:
# ---------------------------------------------------------------------
# KeyboardInterrupt                   Traceback (most recent call last)
# <ipython-input-84-d81dddb49558> in <module>
#      15     gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
#      16
# ---> 17     faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#      18 #     print('FACES', faces)
#      19
#
# KeyboardInterrupt:

# %%
gray.shape
# Out:
# (720, 1280)

# %%
cap.release()
